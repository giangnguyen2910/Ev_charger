# %%
import requests
import json
import pandas as pd
import numpy as np
import os

# %%
# input strings
key = 'AIzaSyDQC0YbdWlWn1Wl8kVX_xXQ2pTp-5XKglY'
keyword = 'car-charger'
lat, lng = "-37.8182711", "144.9670618"
radius = "200000"

# %%
url = f'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={lat},{lng}&radius={radius}&keyword={keyword}&key={key}'

# %%
res = requests.request('GET', url)

# %%
jsonData = res.text

# %%
data = json.loads(jsonData)

# %%
# create a json data file 
with open('data.json', 'w') as f:
    f.write(res.text)

# %%
names = [i["name"] for i in data["results"]]

# %%
df = pd.DataFrame()

# %%
# input data into pandas df
df['Business Status'] = [i['business_status'] for i in data['results']]
df['location'] = [i['geometry'] for i in data['results']]
df['Lat'] = [df['location'][i]['location']['lat'] for i in range(len(df['location']))]
df['Lng'] = [df['location'][i]['location']['lng'] for i in range(len(df['location']))]
df['northeast'] = [df['location'][i]['viewport']['northeast'] for i in range(len(df['location']))]
df['View Port Lat'] = [df['northeast'][i]['lat'] for i in range(len(df['northeast']))]
df['View Port Lng'] = [df['northeast'][i]['lat'] for i in range(len(df['northeast']))]
df['Icon'] = [i['icon'] for i in data['results']]
df['Icon Background Color'] = [i['icon_background_color'] for i in data['results']]
df['Icon Mask Base Uri'] = [i['icon_mask_base_uri'] for i in data['results']]
df['Charger Name'] = [i['name'] for i in data['results']]
df['Rating'] = [i['rating'] for i in data['results']]
df['Reference'] = [i['reference'] for i in data['results']]
df['Scope'] = [i['scope'] for i in data['results']]
df['Types'] = [i['types'] for i in data['results']]
df['User Rating Total'] = [i['user_ratings_total'] for i in data['results']]
df['Vicinity'] = [i['vicinity'] for i in data['results']]
df['plus_code'] = [i['plus_code'] for i in data['results']]
df['Compound Code'] = [df['plus_code'][i]['compound_code'] for i in range(len(df['plus_code']))]
df['Global Code'] = [df['plus_code'][i]['global_code'] for i in range(len(df['plus_code']))]

# %%
# delete unneccessary columns
df.drop(['location', 'northeast', 'plus_code'], axis = 1, inplace = True)

# %%
df
# Out:
#    Business Status        Lat         Lng  View Port Lat  View Port Lng  \
# 0      OPERATIONAL -37.820862  145.039825     -37.819531     -37.819531
# 1      OPERATIONAL -37.886676  145.081194     -37.884932     -37.884932
# 2      OPERATIONAL -37.903185  145.095482     -37.901817     -37.901817
# 3      OPERATIONAL -37.832143  144.995688     -37.830797     -37.830797
# 4      OPERATIONAL -37.942772  145.117778     -37.941429     -37.941429
# 5      OPERATIONAL -37.971644  145.223748     -37.970167     -37.970167
# 6      OPERATIONAL -37.765595  144.922798     -37.764385     -37.764385
# 7      OPERATIONAL -37.950902  145.080350     -37.949336     -37.949336
# 8      OPERATIONAL -37.783617  145.126103     -37.782249     -37.782249
# 9      OPERATIONAL -37.785255  145.125793     -37.784096     -37.784096
# 10     OPERATIONAL -37.801398  144.942794     -37.800040     -37.800040
# 11     OPERATIONAL -37.683060  145.071000     -37.681712     -37.681712
# 12     OPERATIONAL -37.813995  144.967317     -37.812724     -37.812724
# 13     OPERATIONAL -37.848661  144.992530     -37.847417     -37.847417
# 14     OPERATIONAL -37.813247  144.937184     -37.811545     -37.811545
# 15     OPERATIONAL -37.921928  145.157535     -37.920588     -37.920588
# 16     OPERATIONAL -37.844874  145.042095     -37.843531     -37.843531
# 17     OPERATIONAL -37.816238  144.970955     -37.814521     -37.814521
# 18     OPERATIONAL -37.907829  145.131139     -37.906293     -37.906293
# 19     OPERATIONAL -37.958461  145.054851     -37.955936     -37.955936
#
#                                                  Icon Icon Background Color  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...               #7B9EB0
#
#                                    Icon Mask Base Uri  \
# 0   https://maps.gstatic.com/mapfiles/place_api/ic...
# 1   https://maps.gstatic.com/mapfiles/place_api/ic...
# 2   https://maps.gstatic.com/mapfiles/place_api/ic...
# 3   https://maps.gstatic.com/mapfiles/place_api/ic...
# 4   https://maps.gstatic.com/mapfiles/place_api/ic...
# 5   https://maps.gstatic.com/mapfiles/place_api/ic...
# 6   https://maps.gstatic.com/mapfiles/place_api/ic...
# 7   https://maps.gstatic.com/mapfiles/place_api/ic...
# 8   https://maps.gstatic.com/mapfiles/place_api/ic...
# 9   https://maps.gstatic.com/mapfiles/place_api/ic...
# 10  https://maps.gstatic.com/mapfiles/place_api/ic...
# 11  https://maps.gstatic.com/mapfiles/place_api/ic...
# 12  https://maps.gstatic.com/mapfiles/place_api/ic...
# 13  https://maps.gstatic.com/mapfiles/place_api/ic...
# 14  https://maps.gstatic.com/mapfiles/place_api/ic...
# 15  https://maps.gstatic.com/mapfiles/place_api/ic...
# 16  https://maps.gstatic.com/mapfiles/place_api/ic...
# 17  https://maps.gstatic.com/mapfiles/place_api/ic...
# 18  https://maps.gstatic.com/mapfiles/place_api/ic...
# 19  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                       Charger Name  Rating                    Reference  \
# 0     ChargePoint Charging Station     5.0  ChIJi78iPy1C1moRdm-kTEA4AuM
# 1        Tesla Destination Charger     4.3  ChIJE9r2lGhq1moRcqdSmrmBUQM
# 2   EVolution Electric Car Charger     5.0  ChIJm03yiuhr1moRbuWia5dB4ac
# 3               Tesla Supercharger     4.9  ChIJ4dCvlY9C1moR2HtYKzTzUD4
# 4            EVup Charging Station     3.0  ChIJeejL4VJr1moRW5jAOWSPLxk
# 5            Evie Charging Station     4.2  ChIJLZJ90CAU1moR3_zxa-qrBSc
# 6               Tesla Supercharger     3.3  ChIJSQto7_Nc1moRKbAVdsd9hko
# 7     ChargePoint Charging Station     5.0  ChIJJ0tpk89r1moRD1I8RpT_sg4
# 8        Tesla Destination Charger     2.2  ChIJQULuHHBH1moRE0XhZ4kTiQA
# 9     ChargePoint Charging Station     2.0  ChIJIcimmm9H1moRi2X6u-hGpfo
# 10                      JET Charge     4.9  ChIJv-Kjmz5d1moR4Lqk8EUGbCY
# 11           Evie Charging Station     2.0  ChIJXxCm1N9I1moR7f2S-vSEcM8
# 12    ChargePoint Charging Station     0.0  ChIJrfH_ArZC1moRm4Ub55FKXDY
# 13      Chargefox Charging Station     5.0  ChIJ8S_zxG1p1moR2lRGkD76z0o
# 14       Tesla Destination Charger     0.0  ChIJuehJ2Gdd1moRpy4GVD5mc7s
# 15    ChargePoint Charging Station     0.0  ChIJt084tj0V1moRLyP0S7fgric
# 16    ChargePoint Charging Station     5.0  ChIJj9BTxhtC1moRoENkhlYIQEA
# 17       Tesla Destination Charger     0.0  ChIJN-dP6rdC1moRlIzWLySQuuM
# 18      Chargefox Charging Station     5.0  ChIJyUXhqc1q1moRDts0lKArYdg
# 19    ChargePoint Charging Station     0.0  ChIJC4Eg1iNs1moRpJKWuKUExfQ
#
#      Scope                               Types  User Rating Total  \
# 0   GOOGLE  [point_of_interest, establishment]                  4
# 1   GOOGLE  [point_of_interest, establishment]                  3
# 2   GOOGLE  [point_of_interest, establishment]                  1
# 3   GOOGLE  [point_of_interest, establishment]                 47
# 4   GOOGLE  [point_of_interest, establishment]                  4
# 5   GOOGLE  [point_of_interest, establishment]                  6
# 6   GOOGLE  [point_of_interest, establishment]                 11
# 7   GOOGLE  [point_of_interest, establishment]                  1
# 8   GOOGLE  [point_of_interest, establishment]                  5
# 9   GOOGLE  [point_of_interest, establishment]                  1
# 10  GOOGLE  [point_of_interest, establishment]                 23
# 11  GOOGLE  [point_of_interest, establishment]                  1
# 12  GOOGLE  [point_of_interest, establishment]                  0
# 13  GOOGLE  [point_of_interest, establishment]                  1
# 14  GOOGLE  [point_of_interest, establishment]                  0
# 15  GOOGLE  [point_of_interest, establishment]                  0
# 16  GOOGLE  [point_of_interest, establishment]                  1
# 17  GOOGLE  [point_of_interest, establishment]                  0
# 18  GOOGLE  [point_of_interest, establishment]                  1
# 19  GOOGLE  [point_of_interest, establishment]                  0
#
#                                              Vicinity  \
# 0                             20 William St, Hawthorn
# 1                        1341 Dandenong Rd, Chadstone
# 2                         28 Westminster St, Oakleigh
# 3                             650 Church St, Cremorne
# 4               Unit 32/536 Clayton Rd, Clayton South
# 5   Ampol Dandenong, CNR STUD RD AND, Heatherton R...
# 6   Moonee Ponds Central Kmart Mall, Moonee Ponds ...
# 7                         20 Corporate Dr, Heatherton
# 8                         619 Doncaster Rd, Doncaster
# 9                         619 Doncaster Rd, Doncaster
# 10                91 Munster Terrace, North Melbourne
# 11                             Janefield Dr, Bundoora
# 12                   200 Little Collins St, Melbourne
# 13                                            Prahran
# 14                        440 Docklands Dr, Docklands
# 15                        783 Springvale Rd, Mulgrave
# 16                       755 Toorak Rd, Hawthorn East
# 17                         114 Flinders St, Melbourne
# 18                           10 Research Way, Clayton
# 19                   1239-1241 Nepean Hwy, Cheltenham
#
#                         Compound Code  Global Code
# 0          52HQ+MW Hawthorn, Victoria  4RJ752HQ+MW
# 1         437J+8F Chadstone, Victoria  4RJ7437J+8F
# 2          33WW+P5 Oakleigh, Victoria  4RJ733WW+P5
# 3          5X9W+47 Cremorne, Victoria  4RJ65X9W+47
# 4     3449+V4 Clayton South, Victoria  4RJ73449+V4
# 5         26HF+8F Dandenong, Victoria  4RJ726HF+8F
# 6      6WMF+Q4 Moonee Ponds, Victoria  4RJ66WMF+Q4
# 7        23XJ+J4 Heatherton, Victoria  4RJ723XJ+J4
# 8         648G+HC Doncaster, Victoria  4RJ7648G+HC
# 9         647G+V8 Doncaster, Victoria  4RJ7647G+V8
# 10  5WXV+C4 North Melbourne, Victoria  4RJ65WXV+C4
# 11         838C+QC Bundoora, Victoria  4RJ7838C+QC
# 12        5XP8+CW Melbourne, Victoria  4RJ65XP8+CW
# 13          5X2V+G2 Prahran, Victoria  4RJ65X2V+G2
# 14        5WPP+PV Docklands, Victoria  4RJ65WPP+PV
# 15         35H5+62 Mulgrave, Victoria  4RJ735H5+62
# 16    524R+3R Hawthorn East, Victoria  4RJ7524R+3R
# 17        5XMC+G9 Melbourne, Victoria  4RJ65XMC+G9
# 18          34RJ+VF Clayton, Victoria  4RJ734RJ+VF
# 19       23R3+JW Cheltenham, Victoria  4RJ723R3+JW

# %%
path = '/Users/giangnguyen/Desktop' 
df.to_csv(os.path.join(path, 'data.csv'))
